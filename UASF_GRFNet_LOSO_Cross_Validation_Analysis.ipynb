# %% [markdown]
# <a href="https://colab.research.google.com/github/ParvinGhaffarzadeh/multi-sensor-grf-estimation/blob/main/UASF_GRFNet_LOSO_Cross_Validation_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/enhanced_uasf_model_final/enhanced_uasf_loso_training_final1.py \
  --data_dir /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37 \
  --save_dir /content/model_outputs_calibrated \
  --extract_stance --force_scale BW \
  --lr 5e-4 --max_epochs 150 \
  --lambda_activity 0.01 \
  --beta_uncertainty 0.2 \
  --calibrate_temperature --target_picp 0.95
# Out:
# ...
# ENHANCED UASF-GRFNet (REAL DATA) — LOSO CV
# ...
# Device: cuda
# Data:   /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37
# Save:   /content/model_outputs_calibrated
# Stance: ON | Force: BW
#
# Loading 587 CSVs from: /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37
# Reading CSVs: 100% 587/587 [00:01<00:00, 421.87it/s]
#
# ✅ Loaded 345 stance trials
#    Force stats (N): mean=695.9, std=339.6, max=4217.2
#    Activity counts: {'walk': 184, 'drop': 76, 'jog': 65, 'run': 20}
# ✅ Participants (10): ['P01', 'P02', 'P03', 'P04', 'P05', 'P06', 'P07', 'P08', 'P09', 'P10']
# ✅ Activities (4): ['drop', 'jog', 'run', 'walk']
# ✅ Global max_length: 187
#
#
# ...
# FOLD 01/10 | test=P01 | val=P02 | train=8 pids
# ...
#
# 📊 Fold 01 Activity Distribution:
#    Train: {'drop': 60, 'jog': 54, 'walk': 151, 'run': 20}
#    Val:   {'drop': 7, 'jog': 10, 'walk': 11}
#    Test:  {'drop': 9, 'jog': 1, 'walk': 22}
# Dataset: 285 trials, max_length=187, force_scale=BW
# ...

# %%
# !python /content/enhanced_uasf_model_final/enhanced_uasf_loso_training_final_calib97_FIXED.py \
  --data_dir /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37 \
  --save_dir /content/model_outputs_calibrated \
  --extract_stance --force_scale BW \
  --lr 5e-4 --max_epochs 150 \
  --lambda_activity 0.01 \
  --beta_uncertainty 0.2 \
  --calibrate_temperature --target_picp 0.95
# Out:
# ...
# ENHANCED UASF-GRFNet (REAL DATA) — LOSO CV
# ...
# Device: cuda
# Data:   /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37
# Save:   /content/model_outputs_calibrated
# Stance: ON | Force: BW
#
# Loading 587 CSVs from: /content/extracted_data/Dataset_Aligned_FINAL_forcheck_2Jan_v37
# Reading CSVs: 100% 587/587 [00:01<00:00, 451.04it/s]
#
# ✅ Loaded 345 stance trials
#    Force stats (N): mean=695.9, std=339.6, max=4217.2
#    Activity counts: {'walk': 184, 'drop': 76, 'jog': 65, 'run': 20}
# ✅ Participants (10): ['P01', 'P02', 'P03', 'P04', 'P05', 'P06', 'P07', 'P08', 'P09', 'P10']
# ✅ Activities (4): ['drop', 'jog', 'run', 'walk']
# ✅ Global max_length: 187
#
#
# ...
# FOLD 01/10 | test=P01 | val=P02 | train=8 pids
# ...
#
# 📊 Fold 01 Activity Distribution:
#    Train: {'drop': 60, 'jog': 54, 'walk': 151, 'run': 20}
#    Val:   {'drop': 7, 'jog': 10, 'walk': 11}
#    Test:  {'drop': 9, 'jog': 1, 'walk': 22}
# Dataset: 285 trials, max_length=187, force_scale=BW
# ...
